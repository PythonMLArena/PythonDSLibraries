# %%
import pandas as pd 
df=pd.read_csv("nyc_weather.csv")

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# ...

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
df['Temperature'].max()
# Out:
# 50

# %%
df[df["Events"]=="Rain"]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 15  1/16/2016           47        37        70                 29.52
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# 15                8           7.0            0.24           7   Rain
# 26               10           7.0               T           3   Rain
#
#     WindDirDegrees
# 8               76
# 9              109
# 15             340
# 26             311

# %%
df['EST'][df["Events"]=="Rain"]
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
df['WindSpeedMPH'].mean()
# Out:
# 6.892857142857143

# %%
df['WindSpeedMPH'].median()
# Out:
# 6.5

# %%
weather_data=[('1/1/2017',32,6,"Rain"),('1/2/2017',35,7,"Sunny"),('1/3/2017',28,2,"Snow"),('1/4/2017',24,7,"Snow"),('1/5/2017',32,4,"Rain"),('1/6/2017',31,2,"Sunny")]

# %%
df=pd.DataFrame(weather_data,columns=["day","temperature","windspeed","event"])

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.shape# rows and column
# Out:
# (6, 4)

# %%
df.head()
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain

# %%
df.tail()
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df[2:5]# from 2nd row to till 5th row
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow
# 4  1/5/2017           32          4  Rain

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df['day']
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df[['day','event']]
# Out:
#         day  event
# 0  1/1/2017   Rain
# 1  1/2/2017  Sunny
# 2  1/3/2017   Snow
# 3  1/4/2017   Snow
# 4  1/5/2017   Rain
# 5  1/6/2017  Sunny

# %%
df['temperature'].max()
# Out:
# 35

# %%
df['temperature'].min()
# Out:
# 24

# %%
df['temperature'].describe()
# Out:
# count     6.000000
# mean     30.333333
# std       3.829708
# min      24.000000
# 25%      28.750000
# 50%      31.500000
# 75%      32.000000
# max      35.000000
# Name: temperature, dtype: float64

# %%
df[df['temperature']==df.temperature.max()]
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny

# %%
df.day[df['temperature']==df.temperature.max()]
# Out:
# 1    1/2/2017
# Name: day, dtype: object

# %%
df.to_csv("New.csv")

# %%
df.to_csv("New.csv",index=False)

# %%
df.to_excel("new1.xlsx",sheet_name="Weather_data")

# %%
weather_data=[('1/1/2017',"new york",32,6,"Rain"),('1/2/2017',"new york",36,7,"Sunny"),('1/3/2017',"new york",28,12,"Snow"),('1/4/2017',"new york",33,7,"Sunny"),('1/1/2017',"Mumbai",90,5,"Sunny"),('1/2/2017',"Mumbai",85,12,"Fog"),('1/3/2017',"Mumbai",87,15,"Fog"),('1/4/2017',"Mumbai",92,5,"Rain"),('1/1/2017',"paris",45,20,"Sunny"),('1/2/2017',"paris",50,13,"Sunny"),('1/3/2017',"paris",54,8,"Sunny"),('1/4/2017',"paris",42,10,"Cloudy")]

# %%
df=pd.DataFrame(weather_data,columns=["day","city","temperature","windspeed","event"])

# %%
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    Mumbai           90          5   Sunny
# 5   1/2/2017    Mumbai           85         12     Fog
# 6   1/3/2017    Mumbai           87         15     Fog
# 7   1/4/2017    Mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13   Sunny
# 10  1/3/2017     paris           54          8   Sunny
# 11  1/4/2017     paris           42         10  Cloudy

# %%
g=df.groupby("city")#group rows contain same city name

# %%
g

# %%
for city,city_df in g:
    print(city)
    print(city_df)
    print("**************")
# Out:
# Mumbai
#         day    city  temperature  windspeed  event
# 4  1/1/2017  Mumbai           90          5  Sunny
# 5  1/2/2017  Mumbai           85         12    Fog
# 6  1/3/2017  Mumbai           87         15    Fog
# 7  1/4/2017  Mumbai           92          5   Rain
# **************
# new york
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# **************
# paris
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13   Sunny
# 10  1/3/2017  paris           54          8   Sunny
# 11  1/4/2017  paris           42         10  Cloudy
# **************

# %%
g.get_group("paris")
# Out:
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13   Sunny
# 10  1/3/2017  paris           54          8   Sunny
# 11  1/4/2017  paris           42         10  Cloudy

# %%
g.get_group("new york")
# Out:
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny

# %%
g.max()
# Out:
#                day  temperature  windspeed  event
# city
# Mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
g.mean()
# Out:
#           temperature  windspeed
# city
# Mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
g.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# Mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# Mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
india_weather=pd.DataFrame({"city":["Mumbai","delhi","Bangaluru"],"temperatur":[32,45,30],"humudity":[80,60,78]})

# %%
india_weather
# Out:
#         city  temperatur  humudity
# 0     Mumbai          32        80
# 1      delhi          45        60
# 2  Bangaluru          30        78

# %%
us_weather=pd.DataFrame({"city":["New_york","Chicago","Orlando"],"temperatur":[21,14,35],"humudity":[68,65,75]})

# %%
us_weather
# Out:
#        city  temperatur  humudity
# 0  New_york          21        68
# 1   Chicago          14        65
# 2   Orlando          35        75

# %%
df=pd.concat([india_weather,us_weather])

# %%
df
# Out:
#         city  temperatur  humudity
# 0     Mumbai          32        80
# 1      delhi          45        60
# 2  Bangaluru          30        78
# 0   New_york          21        68
# 1    Chicago          14        65
# 2    Orlando          35        75

# %%
df=pd.concat([india_weather,us_weather],ignore_index=True)

# %%
df
# Out:
#         city  temperatur  humudity
# 0     Mumbai          32        80
# 1      delhi          45        60
# 2  Bangaluru          30        78
# 3   New_york          21        68
# 4    Chicago          14        65
# 5    Orlando          35        75

# %%
df=pd.concat([india_weather,us_weather],axis=1)

# %%
df
# Out:
#         city  temperatur  humudity      city  temperatur  humudity
# 0     Mumbai          32        80  New_york          21        68
# 1      delhi          45        60   Chicago          14        65
# 2  Bangaluru          30        78   Orlando          35        75

# %%
temp_weather=pd.DataFrame({"city":["Mumbai","delhi","Bangaluru","hyderabad"],"temperature":[32,45,30,40]})

# %%
temp_weather
# Out:
#         city  temperature
# 0     Mumbai           32
# 1      delhi           45
# 2  Bangaluru           30
# 3  hyderabad           40

# %%
hum_weather=pd.DataFrame({"city":["delhi","Mumbai","Bangaluru"],"humiduty":[68,65,75]})

# %%
hum_weather
# Out:
#         city  humiduty
# 0      delhi        68
# 1     Mumbai        65
# 2  Bangaluru        75

# %%
pd.merge(temp_weather,hum_weather,on="city")#like join (inner join)
# Out:
#         city  temperature  humiduty
# 0     Mumbai           32        65
# 1      delhi           45        68
# 2  Bangaluru           30        75

# %%
pd.merge(temp_weather,hum_weather,on="city",how="outer")#outer join
# Out:
#         city  temperature  humiduty
# 0     Mumbai           32      65.0
# 1      delhi           45      68.0
# 2  Bangaluru           30      75.0
# 3  hyderabad           40       NaN

# %%
.loc[]#using index to access data

# %%
.iloc[]#using row number u get data

# %%
.loc{:2}# will get value till index 2(index 2 included)

# %%
.iloc{:2}#only get first 2 rows
